# %% [markdown]
# # PromptLedger API Demo
#
# Manual test notebook for a live PromptLedger deployment (Railway or local).
# Run cells top-to-bottom. Each section is independently re-runnable.
#
# ## Sections
# 1. Configuration & connectivity
# 2. Full Mode — API-managed prompts
# 3. Tracking Mode — code-based prompts
# 4. Analytics
# 5. Span ingestion & trace observability
# 6. Real-world workflow examples
# 7. Unified `execute()` — Mode 2 with auto-span *(FR-003)*

# %% [markdown]
# ## Step 1: Configuration
#
# Set your Railway deployment URL and API key below, or export them as environment variables before launching Jupyter:
#
# ```bash
# export PROMPTLEDGER_URL=https://your-app.up.railway.app
# export PROMPTLEDGER_API_KEY=your-api-key
# jupyter notebook
# ```

# %%
import os
import requests
import json
import time
from datetime import datetime, timezone
from typing import Dict, Any, Optional

# --- Configure these for your deployment ---
BASE_URL = os.environ.get("PROMPTLEDGER_URL", "https://prompt-ledger-api-production.up.railway.app").rstrip("/")
API_KEY  = os.environ.get("PROMPTLEDGER_API_KEY") or "dev-key-change-in-production"
# To override without env vars, uncomment and paste your key:
API_KEY = "srzd9tfqxxtvjlalswsy2662rerdutjj"
# -------------------------------------------

if not API_KEY or API_KEY == "dev-key-change-in-production":
    print("⚠  WARNING: using default API key — set PROMPTLEDGER_API_KEY or paste your key above")

API_V1 = f"{BASE_URL}/v1"

# Auth header only — requests adds Content-Type: application/json automatically
# when json= is passed to a POST/PUT. Sending it on GETs causes a 500.
HEADERS = {"X-API-Key": API_KEY}

def print_response(response: requests.Response, title: str = "Response") -> None:
    """Pretty-print an API response."""
    status_icon = "✓" if response.status_code < 400 else "✗"
    print(f"\n{'='*60}")
    print(f"{status_icon} {title}")
    print(f"{'='*60}")
    print(f"Status: {response.status_code}")
    try:
        print(json.dumps(response.json(), indent=2))
    except Exception:
        print(response.text)
    print(f"{'='*60}\n")

def now_iso() -> str:
    return datetime.now(timezone.utc).isoformat()

masked = f"{'*' * (len(API_KEY) - 4)}{API_KEY[-4:]}" if len(API_KEY) > 4 else "****"
print(f"Target:  {BASE_URL}")
print(f"API key: {masked}")
# Out:
# Target:  https://prompt-ledger-api-production.up.railway.app
# API key: ****************************utjj

# %% [markdown]
# ## Step 2: Health Check
#
# Verify the deployment is reachable before running any tests.
# If this fails, check that your Railway service is awake and `BASE_URL` is correct.

# %%
response = requests.get(f"{BASE_URL}/health", timeout=30)
print_response(response, "Health Check")

if response.status_code == 200:
    print("✓ Deployment is healthy — ready to test")
else:
    print("✗ Deployment not responding — check Railway dashboard")
# Out:
# ...
# ✓ Health Check
# ...
# Status: 200
# {
#   "status": "healthy"
# }
# ...
#
# ✓ Deployment is healthy — ready to test

# %% [markdown]
# ## Step 3: Auth Check
#
# Verify the API key is accepted. Expect 200 with a valid key, 401 with a wrong key.

# %%
# Valid key — should return 200
response = requests.get(f"{API_V1}/analytics/prompts", headers=HEADERS, timeout=30)
print_response(response, "Auth check (valid key)")

# Wrong key — should return 401
response = requests.get(f"{API_V1}/analytics/prompts", headers={"X-API-Key": "wrong-key"}, timeout=30)
print_response(response, "Auth check (wrong key — expect 401)")
# Out:
# ...
# ✓ Auth check (valid key)
# ...
# Status: 200
# {
#   "summary": {
#     "total_executions": 26,
#     "full_mode_prompts": 3,
#     "tracking_mode_prompts": 9,
#     "total_cost": 0.00240255
#   },
#   "by_mode": {
#     "full": {
#       "execution_count": 18,
#       "avg_latency_ms": 3658
#     },
#     "tracking": {
#       "execution_count": 8,
#       "avg_latency_ms": 1257
#     }
#   }
# }
# ...
#
#
# ...
# ✗ Auth check (wrong key — expect 401)
# ...
# Status: 401
# {
#   "detail": "Invalid or missing API key"
# }
# ...

# %% [markdown]
# ---
# ## Part 1: Full Mode — API-Managed Prompts
#
# Prompts are created, versioned, and executed entirely through the API.
# Best for: centralised prompt management, non-engineer editors, dynamic updates without redeploy.

# %%
# 1.1 Create a prompt (or update if it already exists)
response = requests.put(
    f"{API_V1}/prompts/demo_email_generator",
    headers=HEADERS,
    json={
        "template_source": "Generate a professional email to {{recipient}} about {{topic}}.",
        "description": "Email generation template",
        "owner_team": "demo",
        "created_by": "api_demo_notebook",
        "set_active": True,
    },
    timeout=30,
)
print_response(response, "1.1 Create prompt (Full Mode)")
# Out:
# ...
# ✓ 1.1 Create prompt (Full Mode)
# ...
# Status: 200
# {
#   "prompt": {
#     "prompt_id": "bae910bd-48d7-401a-b24f-27c324767b0a",
#     "name": "demo_email_generator"
#   },
#   "version": {
#     "version_id": "89ff5b6d-5457-4550-a979-d933b996a2cc",
#     "version_number": 1
#   },
#   "version_change": false
# }
# ...

# %%
# 1.2 Get prompt details
response = requests.get(
    f"{API_V1}/prompts/demo_email_generator",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "1.2 Get prompt details")
# Out:
# ...
# ✓ 1.2 Get prompt details
# ...
# Status: 200
# {
#   "prompt_id": "bae910bd-48d7-401a-b24f-27c324767b0a",
#   "name": "demo_email_generator",
#   "description": "Email generation template",
#   "owner_team": "demo",
#   "created_at": "2026-03-16T02:42:48.268918+00:00",
#   "updated_at": "2026-03-18T19:11:52.999815+00:00",
#   "active_version": {
#     "version_id": "89ff5b6d-5457-4550-a979-d933b996a2cc",
#     "version_number": 1,
#     "template_source": "Generate a professional email to {{recipient}} about {{topic}}.",
#     "status": "active"
#   }
# }
# ...

# %%
# 1.3 Update prompt — creates new version automatically
response = requests.put(
    f"{API_V1}/prompts/demo_email_generator",
    headers=HEADERS,
    json={
        "template_source": "Generate a professional and friendly email to {{recipient}} about {{topic}}. Keep it concise and actionable.",
        "description": "Enhanced email generation template",
        "owner_team": "demo",
        "created_by": "api_demo_notebook",
        "set_active": True,
    },
    timeout=30,
)
print_response(response, "1.3 Update prompt (new version)")
# Out:
# ...
# ✓ 1.3 Update prompt (new version)
# ...
# Status: 200
# {
#   "prompt": {
#     "prompt_id": "bae910bd-48d7-401a-b24f-27c324767b0a",
#     "name": "demo_email_generator"
#   },
#   "version": {
#     "version_id": "771a59fb-dadf-4685-9a1b-f372798296fa",
#     "version_number": 2
#   },
#   "version_change": false
# }
# ...

# %%
# 1.4 List all versions
response = requests.get(
    f"{API_V1}/prompts/demo_email_generator/versions",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "1.4 List versions")
# Out:
# ...
# ✓ 1.4 List versions
# ...
# Status: 200
# [
#   {
#     "version_id": "771a59fb-dadf-4685-9a1b-f372798296fa",
#     "version_number": 2,
#     "status": "active",
#     "checksum_hash": "de758702d335e16200bc0e7ecc42b26969244ecb50f5f687e9fef5d79c688843",
#     "created_by": "api_demo_notebook",
#     "created_at": "2026-03-16T02:45:34.958197+00:00"
#   },
#   {
#     "version_id": "89ff5b6d-5457-4550-a979-d933b996a2cc",
#     "version_number": 1,
#     "status": "active",
#     "checksum_hash": "5f109cc82a8278f251162e28aee30fca17401a31e018bf64420894404b91c65a",
#     "created_by": "api_demo_notebook",
#     "created_at": "2026-03-16T02:42:48.268918+00:00"
#   }
# ]
# ...

# %%
# 1.5 Execute synchronously
# Note: requires OPENAI_API_KEY to be set in Railway environment
response = requests.post(
    f"{API_V1}/executions/run",
    headers=HEADERS,
    json={
        "prompt_name": "demo_email_generator",
        "variables": {"recipient": "Sarah", "topic": "quarterly review"},
        "model": {"provider": "openai", "model_name": "gpt-4o-mini"},
        "params": {"temperature": 0.7, "max_tokens": 300},
        "environment": "demo",
        "correlation_id": "notebook-demo-001",
    },
    timeout=60,
)
print_response(response, "1.5 Execute sync")
# Out:
# ...
# ✓ 1.5 Execute sync
# ...
# Status: 200
# {
#   "execution_id": "2acd35ab-73a4-4152-943e-d86a0235908d",
#   "status": "succeeded",
#   "mode": "sync",
#   "response_text": "Subject: Upcoming Quarterly Review\n\nHi Sarah,\n\nI hope this message finds you well! As we approach the end of the quarter, I\u2019d like to schedule our quarterly review to discuss our progress and set goals for the next quarter.\n\nCould you please let me know your availability next week? I believe it will be a great opportunity to align on our objectives and celebrate our achievements.\n\nLooking forward to your response!\n\nBest regards,  \n[Your Name]  \n[Your Position]  \n[Your Contact Information]  ",
#   "span_id": null,
#   "telemetry": {
#     "prompt_tokens": 25,
#     "response_tokens": 101,
#     "latency_ms": 3459,
#     "model_name": "gpt-4o-mini",
#     "provider": "openai",
#     "total_cost": 6.434999999999999e-05
#   }
# }
# ...

# %%
# 1.6 Execute asynchronously — returns immediately, poll for result
# NOTE: requires a Celery worker process running alongside the API.
# On Railway this means a second "worker" service: celery -A prompt_ledger.workers.celery_app worker
# If you don't have a worker, the job will stay "queued" and cell 1.7 will time out.
response = requests.post(
    f"{API_V1}/executions/submit",
    headers=HEADERS,
    json={
        "prompt_name": "demo_email_generator",
        "variables": {"recipient": "Alex", "topic": "project kickoff"},
        "model": {"provider": "openai", "model_name": "gpt-4o-mini"},
        "params": {"temperature": 0.7, "max_tokens": 300},
        "environment": "demo",
    },
    timeout=30,
)
print_response(response, "1.6 Submit async execution")

async_execution_id = response.json().get("execution_id") if response.status_code == 200 else None
print(f"Execution ID: {async_execution_id}")
# Out:
# ...
# ✓ 1.6 Submit async execution
# ...
# Status: 202
# {
#   "execution_id": "c9de8e08-6f19-4bd3-bd2d-c3db6ee29458",
#   "status": "queued",
#   "mode": "async",
#   "model_name": "gpt-4o-mini",
#   "provider": "openai"
# }
# ...
#
# Execution ID: None

# %%
# 1.7 Poll async execution until complete (max 30s)
if not async_execution_id:
    print("No async_execution_id — run cell 1.6 first")
else:
    queued_count = 0
    for attempt in range(10):
        response = requests.get(
            f"{API_V1}/executions/{async_execution_id}",
            headers=HEADERS,
            timeout=30,
        )
        data = response.json()
        status = data.get("status")
        print(f"Attempt {attempt + 1}: status = {status}")

        if status in ("succeeded", "failed"):
            print_response(response, "1.7 Async execution result")
            break

        if status == "queued":
            queued_count += 1

        time.sleep(3)
    else:
        if queued_count >= 8:
            print(
                "\n✗ Job stayed 'queued' the entire time — no Celery worker is running.\n"
                "  To fix: add a second Railway service with start command:\n"
                "    celery -A prompt_ledger.workers.celery_app worker --loglevel=info\n"
                "  (requires Redis to be provisioned as a Railway service too)\n"
                "\n  Skip to cell 1.5 (sync execution) to test LLM calls without a worker."
            )
        else:
            print("Timed out waiting for execution to complete")
# Out:
# No async_execution_id — run cell 1.6 first

# %% [markdown]
# ---
# ## Part 2: Tracking Mode — Code-Based Prompts
#
# Prompts are defined in application code. PromptLedger tracks version changes automatically.
# Best for: engineering teams, GitOps workflows, non-OpenAI providers (Mode 2 observability).

# %%
# 2.1 Register code-based prompts at startup
DEMO_PROMPTS = {
    "demo.welcome": "Hello {{name}}! Welcome to {{service}}.",
    "demo.error_explain": "Explain this error to a non-technical user: {{error_message}}",
    "demo.code_review": "Review the following {{language}} code and provide constructive feedback:\n\n{{code}}",
}

response = requests.post(
    f"{API_V1}/prompts/register-code",
    headers=HEADERS,
    json={"prompts": [{"name": name, "template_source": tmpl} for name, tmpl in DEMO_PROMPTS.items()]},
    timeout=30,
)
print_response(response, "2.1 Register code prompts")
# Out:
# ...
# ✓ 2.1 Register code prompts
# ...
# Status: 200
# {
#   "registered": 0,
#   "updated": 0,
#   "unchanged": 3,
#   "dry_run": false,
#   "details": [
#     {
#       "name": "demo.welcome",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     },
#     {
#       "name": "demo.error_explain",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     },
#     {
#       "name": "demo.code_review",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     }
#   ]
# }
# ...

# %%
# 2.2 Register again unchanged — no new versions created
response = requests.post(
    f"{API_V1}/prompts/register-code",
    headers=HEADERS,
    json={"prompts": [{"name": name, "template_source": tmpl} for name, tmpl in DEMO_PROMPTS.items()]},
    timeout=30,
)
print_response(response, "2.2 Register again unchanged — expect change_detected: false")
# Out:
# ...
# ✓ 2.2 Register again unchanged — expect change_detected: false
# ...
# Status: 200
# {
#   "registered": 0,
#   "updated": 0,
#   "unchanged": 3,
#   "dry_run": false,
#   "details": [
#     {
#       "name": "demo.welcome",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 2,
#       "change_detected": false,
#       "previous_version": null
#     },
#     {
#       "name": "demo.error_explain",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     },
#     {
#       "name": "demo.code_review",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     }
#   ]
# }
# ...

# %%
# 2.3 Update a prompt and re-register — new version created
DEMO_PROMPTS["demo.welcome"] = "Hello {{name}}! Welcome to {{service}}. We're glad you're here!"

response = requests.post(
    f"{API_V1}/prompts/register-code",
    headers=HEADERS,
    json={"prompts": [{"name": "demo.welcome", "template_source": DEMO_PROMPTS["demo.welcome"]}]},
    timeout=30,
)
print_response(response, "2.3 Register after change — expect change_detected: true")
# Out:
# ...
# ✓ 2.3 Register after change — expect change_detected: true
# ...
# Status: 200
# {
#   "registered": 0,
#   "updated": 0,
#   "unchanged": 1,
#   "dry_run": false,
#   "details": [
#     {
#       "name": "demo.welcome",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 2,
#       "change_detected": false,
#       "previous_version": null
#     }
#   ]
# }
# ...

# %%
# 2.4 Execute a tracking-mode prompt
response = requests.post(
    f"{API_V1}/prompts/demo.welcome/execute",
    headers=HEADERS,
    json={
        "variables": {"name": "Alice", "service": "PromptLedger"},
        "model_name": "gpt-4o-mini",
        "mode": "sync",
        "params": {"temperature": 0.5, "max_tokens": 100},
    },
    timeout=60,
)
print_response(response, "2.4 Execute tracking prompt (sync)")
# Out:
# ...
# ✓ 2.4 Execute tracking prompt (sync)
# ...
# Status: 200
# {
#   "execution_id": "5c7aa19f-1225-4a17-9c7f-e86396d589f9",
#   "status": "succeeded",
#   "mode": "sync",
#   "response_text": "Hello! Thank you for the warm welcome to PromptLedger. I'm excited to be here! How can I assist you today?",
#   "span_id": null,
#   "telemetry": {
#     "prompt_tokens": 20,
#     "response_tokens": 25,
#     "latency_ms": 1317,
#     "model_name": "gpt-4o-mini",
#     "provider": "openai",
#     "total_cost": 1.7999999999999997e-05
#   },
#   "prompt_mode": "tracking"
# }
# ...

# %%
# 2.5 View version history — should show 2 versions for demo.welcome
response = requests.get(
    f"{API_V1}/prompts/demo.welcome/versions",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "2.5 Version history")
# Out:
# ...
# ✓ 2.5 Version history
# ...
# Status: 200
# [
#   {
#     "version_id": "3a254c7c-e95d-4228-8884-2c3ba4991a33",
#     "version_number": 2,
#     "status": "active",
#     "checksum_hash": "0a979face33667be5d41a503d3f799702f030f0dded5986ff0a0e0fa237285b4",
#     "created_by": null,
#     "created_at": "2026-03-16T03:28:17.071590+00:00"
#   },
#   {
#     "version_id": "01094622-f7a2-4876-abce-602546419bac",
#     "version_number": 1,
#     "status": "active",
#     "checksum_hash": "439b0d48ebaa5631eb5a02fbc9284a3f883f7d6601db54a44d39e9c9f360ff08",
#     "created_by": null,
#     "created_at": "2026-03-16T03:26:27.312949+00:00"
#   }
# ]
# ...

# %% [markdown]
# ---
# ## Part 3: Analytics

# %%
# 3.1 Overall analytics across both modes
response = requests.get(
    f"{API_V1}/analytics/prompts?mode=all",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "3.1 Overall analytics")
# Out:
# ...
# ✓ 3.1 Overall analytics
# ...
# Status: 200
# {
#   "summary": {
#     "total_executions": 32,
#     "full_mode_prompts": 3,
#     "tracking_mode_prompts": 9,
#     "total_cost": 0.00268395
#   },
#   "by_mode": {
#     "full": {
#       "execution_count": 22,
#       "avg_latency_ms": 3590
#     },
#     "tracking": {
#       "execution_count": 10,
#       "avg_latency_ms": 1314
#     }
#   }
# }
# ...

# %%
# 3.2 Analytics by mode
for mode in ("full", "tracking"):
    response = requests.get(
        f"{API_V1}/analytics/prompts?mode={mode}",
        headers=HEADERS,
        timeout=30,
    )
    print_response(response, f"3.2 {mode.capitalize()} mode analytics")
# Out:
# ...
# ✓ 3.2 Full mode analytics
# ...
# Status: 200
# {
#   "mode": "full",
#   "prompt_count": 3,
#   "execution_count": 22,
#   "avg_latency_ms": 3590,
#   "total_prompt_tokens": 573,
#   "total_response_tokens": 2462,
#   "total_cost": 0.00156315
# }
# ...
#
#
# ...
# ✓ 3.2 Tracking mode analytics
# ...
# Status: 200
# {
#   "mode": "tracking",
#   "prompt_count": 9,
#   "execution_count": 10,
#   "avg_latency_ms": 1314,
#   "total_prompt_tokens": 223,
#   "total_response_tokens": 419,
#   "total_cost": 0.0011208000000000001
# }
# ...

# %%
# 3.3 Recent executions
response = requests.get(
    f"{API_V1}/executions/?limit=10",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "3.3 Recent executions")
# Out:
# ...
# ✓ 3.3 Recent executions
# ...
# Status: 200
# {
#   "executions": [
#     {
#       "execution_id": "5c7aa19f-1225-4a17-9c7f-e86396d589f9",
#       "prompt_name": "demo.welcome",
#       "status": "succeeded",
#       "mode": "sync",
#       "model_name": "gpt-4o-mini",
#       "created_at": "2026-03-18T19:14:38.111795+00:00",
#       "completed_at": "2026-03-18T19:14:38.111795+00:00"
#     },
#     {
#       "execution_id": "4dc102db-afbe-475b-a8d6-f57ba49c3b98",
#       "prompt_name": "demo.welcome",
#       "status": "succeeded",
#       "mode": "sync",
#       "model_name": "gpt-4o-mini",
#       "created_at": "2026-03-18T19:13:31.551268+00:00",
#       "completed_at": "2026-03-18T19:13:31.551268+00:00"
#     },
#     {
#       "execution_id": "c9de8e08-6f19-4bd3-bd2d-c3db6ee29458",
#       "prompt_name": "demo_email_generator",
#       "status": "succeeded",
#       "mode": "async",
#       "model_name": "gpt-4o-mini",
#       "created_at": "2026-03-18T19:13:01.336595+00:00",
# ...

# %%
# 3.4 Filter executions by prompt
response = requests.get(
    f"{API_V1}/executions/?prompt_name=demo.welcome&limit=5",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "3.4 Executions for demo.welcome")
# Out:
# ...
# ✓ 3.4 Executions for demo.welcome
# ...
# Status: 200
# {
#   "executions": [
#     {
#       "execution_id": "5c7aa19f-1225-4a17-9c7f-e86396d589f9",
#       "prompt_name": "demo.welcome",
#       "status": "succeeded",
#       "mode": "sync",
#       "model_name": "gpt-4o-mini",
#       "created_at": "2026-03-18T19:14:38.111795+00:00",
#       "completed_at": "2026-03-18T19:14:38.111795+00:00"
#     },
#     {
#       "execution_id": "4dc102db-afbe-475b-a8d6-f57ba49c3b98",
#       "prompt_name": "demo.welcome",
#       "status": "succeeded",
#       "mode": "sync",
#       "model_name": "gpt-4o-mini",
#       "created_at": "2026-03-18T19:13:31.551268+00:00",
#       "completed_at": "2026-03-18T19:13:31.551268+00:00"
#     },
#     {
#       "execution_id": "ed8336f2-fc5d-415b-95fc-40319e097c21",
#       "prompt_name": "demo.welcome",
#       "status": "succeeded",
#       "mode": "sync",
#       "model_name": "gpt-4o-mini",
#       "created_at": "2026-03-18T04:47:35.354946+00:00",
# ...

# %% [markdown]
# ---
# ## Part 4: Span Ingestion & Trace Observability
#
# > **Epic 1 Story 1.7 — not yet implemented.**
# > Cells in this section will return 404 until Story 1.7 ships.
# > They are here as the acceptance test for that story.
#
# This section tests Mode 2 observability: logging LLM calls made directly by the client
# back to PromptLedger as spans, then retrieving the trace and cost summary.

# %%
# 4.1 Log spans for a simulated multi-agent workflow
import uuid

TRACE_ID = f"demo-trace-{uuid.uuid4().hex[:8]}"
print(f"Trace ID: {TRACE_ID}")

# Phase span — parent for all turns in the open_discussion phase
response = requests.post(
    f"{API_V1}/spans",
    headers=HEADERS,
    json={
        "trace_id": TRACE_ID,
        "name": "open_discussion",
        "kind": "workflow.phase",
        "start_time": now_iso(),
        "status": "ok",
    },
    timeout=30,
)
print_response(response, "4.1a Log phase span")
phase_span_id = response.json().get("span_id") if response.status_code == 201 else None

# Turn span — paper_1 agent LLM call
response = requests.post(
    f"{API_V1}/spans",
    headers=HEADERS,
    json={
        "trace_id": TRACE_ID,
        "parent_span_id": phase_span_id,
        "agent_id": "paper_1",
        "prompt_name": "paper_agent_discussion",
        "name": "paper_1.turn_3",
        "kind": "llm.generation",
        "start_time": now_iso(),
        "status": "ok",
        "model": "claude-sonnet-4-6",
        "prompt_tokens": 412,
        "completion_tokens": 198,
        "duration_ms": 1340,
    },
    timeout=30,
)
print_response(response, "4.1b Log turn span (paper_1)")
turn_span_id = response.json().get("span_id") if response.status_code == 201 else None

# Guardrail child span
response = requests.post(
    f"{API_V1}/spans",
    headers=HEADERS,
    json={
        "trace_id": TRACE_ID,
        "parent_span_id": turn_span_id,
        "agent_id": "guardrail",
        "name": "guardrail.check_turn_3",
        "kind": "guardrail.check",
        "start_time": now_iso(),
        "status": "ok",
        "model": "claude-sonnet-4-6",
        "prompt_tokens": 680,
        "completion_tokens": 42,
        "duration_ms": 890,
        "attributes": {"violations_found": 0},
    },
    timeout=30,
)
print_response(response, "4.1c Log guardrail child span")
# Out:
# Trace ID: demo-trace-f0fdf49e
#
# ...
# ✓ 4.1a Log phase span
# ...
# Status: 201
# {
#   "span_id": "f139cd18-b301-431b-8c5c-4677f00d04b9"
# }
# ...
#
#
# ...
# ✓ 4.1b Log turn span (paper_1)
# ...
# Status: 201
# {
#   "span_id": "485ac115-17e3-4aef-81cc-19ffb8a42221"
# }
# ...
#
#
# ...
# ✓ 4.1c Log guardrail child span
# ...
# Status: 201
# {
#   "span_id": "4bbf5c40-8f03-4aa7-b854-688d0dfa3800"
# }
# ...

# %%
# 4.2 Retrieve the full trace tree
response = requests.get(
    f"{API_V1}/traces/{TRACE_ID}",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "4.2 Get trace tree")
# Out:
# ...
# ✓ 4.2 Get trace tree
# ...
# Status: 200
# {
#   "trace_id": "demo-trace-f0fdf49e",
#   "span_count": 3,
#   "start_time": "2026-03-18T19:15:16.622826+00:00",
#   "end_time": null,
#   "duration_ms": 2230,
#   "spans": [
#     {
#       "span_id": "f139cd18-b301-431b-8c5c-4677f00d04b9",
#       "parent_span_id": null,
#       "trace_id": "demo-trace-f0fdf49e",
#       "name": "open_discussion",
#       "kind": "workflow.phase",
#       "agent_id": null,
#       "prompt_name": null,
#       "status": "ok",
#       "start_time": "2026-03-18T19:15:16.622826+00:00",
#       "end_time": null,
#       "duration_ms": null,
#       "model": null,
#       "prompt_tokens": null,
#       "completion_tokens": null,
#       "attributes": null,
#       "tool_name": null,
#       "success": null,
#       "tool_args": null,
#       "tool_result": null,
#       "children": [
#         {
#           "span_id": "485ac115-17e3-4aef-81cc-19ffb8a42221",
# ...

# %%
# 4.3 Get trace cost summary with by_agent breakdown
response = requests.get(
    f"{API_V1}/traces/{TRACE_ID}/summary",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "4.3 Trace cost summary (by_agent)")
# Out:
# ...
# ✓ 4.3 Trace cost summary (by_agent)
# ...
# Status: 200
# {
#   "trace_id": "demo-trace-f0fdf49e",
#   "span_count": 3,
#   "total_prompt_tokens": 1092,
#   "total_completion_tokens": 240,
#   "total_cost": 0.006876,
#   "cost_breakdown": [
#     {
#       "span_name": "open_discussion",
#       "agent_id": null,
#       "cost": null,
#       "provider": null
#     },
#     {
#       "span_name": "paper_1.turn_3",
#       "agent_id": "paper_1",
#       "cost": 0.004206,
#       "provider": "anthropic"
#     },
#     {
#       "span_name": "guardrail.check_turn_3",
#       "agent_id": "guardrail",
#       "cost": 0.00267,
#       "provider": "anthropic"
#     }
#   ],
#   "by_agent": [
#     {
#       "agent_id": "paper_1",
#       "span_count": 1,
#       "total_cost": 0.004206,
#       "total_prompt_tokens": 412
#     },
#     {
#       "agent_id": "guardrail",
#       "span_count": 1,
#       "total_cost": 0.00267,
#       "total_prompt_tokens": 680
#     }
#   ],
# ...

# %%
# 4.4 Cross-trace agent analytics
response = requests.get(
    f"{API_V1}/analytics/agents",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "4.4 Agent analytics (cross-trace)")
# Out:
# ...
# ✓ 4.4 Agent analytics (cross-trace)
# ...
# Status: 200
# {
#   "agents": [
#     {
#       "agent_id": "guardrail",
#       "total_spans": 9,
#       "total_cost": null,
#       "avg_latency_ms": 890,
#       "avg_prompt_tokens": 413
#     },
#     {
#       "agent_id": "e2e_agent",
#       "total_spans": 5,
#       "total_cost": null,
#       "avg_latency_ms": 1340,
#       "avg_prompt_tokens": 412
#     },
#     {
#       "agent_id": "paper_1",
#       "total_spans": 4,
#       "total_cost": null,
#       "avg_latency_ms": 1340,
#       "avg_prompt_tokens": 412
#     },
#     {
#       "agent_id": "researcher",
#       "total_spans": 1,
#       "total_cost": null,
#       "avg_latency_ms": 1978,
#       "avg_prompt_tokens": 29
#     },
#     {
#       "agent_id": "agent_a",
#       "total_spans": 1,
#       "total_cost": null,
#       "avg_latency_ms": 983,
#       "avg_prompt_tokens": 30
#     },
#     {
#       "agent_id": "agent_b",
#       "total_spans": 1,
# ...

# %%
# 4.5 Filter agent analytics to guardrail spans only
response = requests.get(
    f"{API_V1}/analytics/agents?kind=guardrail.check",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "4.5 Guardrail span analytics")
# Out:
# ...
# ✓ 4.5 Guardrail span analytics
# ...
# Status: 200
# {
#   "agents": [
#     {
#       "agent_id": "guardrail",
#       "total_spans": 9,
#       "total_cost": null,
#       "avg_latency_ms": 890,
#       "avg_prompt_tokens": 413
#     }
#   ]
# }
# ...

# %% [markdown]
# ---
# ## Part 5: Real-World Workflow Examples

# %%
# 5.1 Full Mode: create, draft, test, promote
prompt_name = "demo_marketing_msg"

# v1 — initial
requests.put(f"{API_V1}/prompts/{prompt_name}", headers=HEADERS, timeout=30, json={
    "template_source": "Create a marketing message for {{product}} targeting {{audience}}.",
    "owner_team": "demo", "set_active": True,
})

# v2 — draft improved version
r = requests.put(f"{API_V1}/prompts/{prompt_name}", headers=HEADERS, timeout=30, json={
    "template_source": "Create an engaging marketing message for {{product}} that resonates with {{audience}}. Focus on benefits, use emotional language, and end with a call to action.",
    "owner_team": "demo", "set_active": False,
})
v2 = r.json().get("version", {}).get("version_number")
print(f"Draft version: {v2}")

# Test the draft
response = requests.post(f"{API_V1}/executions/run", headers=HEADERS, timeout=60, json={
    "prompt_name": prompt_name,
    "version_number": v2,
    "variables": {"product": "PromptLedger", "audience": "GenAI developers"},
    "model": {"provider": "openai", "model_name": "gpt-4o-mini"},
    "environment": "staging",
})
print_response(response, "5.1 Test draft version")

# Promote draft to active
requests.put(f"{API_V1}/prompts/{prompt_name}", headers=HEADERS, timeout=30, json={
    "template_source": "Create an engaging marketing message for {{product}} that resonates with {{audience}}. Focus on benefits, use emotional language, and end with a call to action.",
    "owner_team": "demo", "set_active": True,
})
print("Promoted draft to active")
# Out:
# Draft version: 2
#
# ...
# ✓ 5.1 Test draft version
# ...
# Status: 200
# {
#   "execution_id": "fd353962-b6ec-4255-b538-efe0f21d7fff",
#   "status": "succeeded",
#   "mode": "sync",
# ...

# %%
# 5.2 Tracking Mode: simulate app startup registration across two deploys

class AppPrompts:
    """Simulates prompt definitions living in application code."""
    USER_ONBOARDING     = "Welcome {{user_name}}! Let's get you started with {{feature}}."
    FEATURE_ANNOUNCEMENT = "Exciting news! We just released {{feature_name}}. {{description}}"

# Deploy 1 — initial registration
response = requests.post(f"{API_V1}/prompts/register-code", headers=HEADERS, timeout=30, json={
    "prompts": [
        {"name": "demo.user_onboarding",      "template_source": AppPrompts.USER_ONBOARDING},
        {"name": "demo.feature_announcement", "template_source": AppPrompts.FEATURE_ANNOUNCEMENT},
    ]
})
print_response(response, "5.2a Deploy 1 — initial registration")

# Developer edits the prompt in code
AppPrompts.USER_ONBOARDING = "Welcome {{user_name}}! We're thrilled to have you. Let's explore {{feature}} together."

# Deploy 2 — new version auto-detected
response = requests.post(f"{API_V1}/prompts/register-code", headers=HEADERS, timeout=30, json={
    "prompts": [
        {"name": "demo.user_onboarding",      "template_source": AppPrompts.USER_ONBOARDING},
        {"name": "demo.feature_announcement", "template_source": AppPrompts.FEATURE_ANNOUNCEMENT},
    ]
})
print_response(response, "5.2b Deploy 2 — change detected for user_onboarding")

# View history
response = requests.get(f"{API_V1}/prompts/demo.user_onboarding/versions", headers=HEADERS, timeout=30)
print_response(response, "5.2c Version history")
# Out:
# ...
# ✓ 5.2a Deploy 1 — initial registration
# ...
# Status: 200
# {
#   "registered": 0,
#   "updated": 0,
#   "unchanged": 2,
#   "dry_run": false,
#   "details": [
#     {
#       "name": "demo.user_onboarding",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     },
#     {
#       "name": "demo.feature_announcement",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     }
#   ]
# }
# ...
#
#
# ...
# ✓ 5.2b Deploy 2 — change detected for user_onboarding
# ...
# Status: 200
# {
#   "registered": 0,
#   "updated": 0,
#   "unchanged": 2,
#   "dry_run": false,
#   "details": [
#     {
#       "name": "demo.user_onboarding",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 2,
#       "change_detected": false,
#       "previous_version": null
#     },
#     {
# ...

# %% [markdown]
# ---
# ## Summary
#
# | Part | Status | What it tests |
# |------|--------|---------------|
# | 1 — Full Mode | ✅ Available | Prompt CRUD, versioning, sync/async execution |
# | 2 — Tracking Mode | ✅ Available | Code-based registration, version change detection |
# | 3 — Analytics | ✅ Available | Execution counts, latency by mode |
# | 4 — Spans & Traces | ✅ Available | Agent span logging, trace tree, cost by agent |
# | 5 — Workflows | ✅ Available | End-to-end multi-step scenarios |
# | 6 — Project Namespacing | ✅ Epic 2 | Admin API: create project, issue key, isolation, revoke |
# | 7 — Unified `execute()` | ✅ Epic 3 | `messages` input, auto-span, state dict threading |
# | 8 — Async Execution | ✅ Epic 3 | `submit` → 202, poll, span context forwarded to worker |
# | 9 — Tool Call Capture | ✅ Epic 4 | `log_tool_call()`, `GET /v1/analytics/tools` |
#
# ### Key endpoints
#
# | Endpoint | Purpose |
# |----------|---------|
# | `GET /health` | Liveness check (no auth required) |
# | `PUT /v1/prompts/{name}` | Create/update prompt (Full Mode) |
# | `POST /v1/prompts/register-code` | Register code-based prompts (Tracking Mode) |
# | `POST /v1/executions/run` | Synchronous execution (returns result immediately) |
# | `POST /v1/executions/submit` | Async execution — returns 202, poll with GET |
# | `GET /v1/executions/{id}` | Poll async execution status |
# | `POST /v1/spans` | Ingest a span (Mode 2 observability) |
# | `GET /v1/traces/{trace_id}` | Retrieve full trace tree |
# | `GET /v1/traces/{trace_id}/summary` | Aggregated cost + token summary |
# | `GET /v1/analytics/prompts` | Execution stats by mode |
# | `GET /v1/analytics/agents` | Cross-trace stats by agent_id |
# | `GET /v1/analytics/tools` | Error rate + latency per tool_name (Epic 4) |
# | `POST /v1/admin/projects` | Create project + issue scoped API key (admin only) |
# | `GET /v1/admin/projects` | List all projects (admin only) |
# | `DELETE /v1/admin/keys/{key_id}` | Revoke an API key (admin only) |

# %% [markdown]
# ---
# ## Part 6: Project Namespacing & Admin API *(Epic 2)*
#
# PromptLedger uses **DB-backed API keys** mapped to projects. The key you set above
# (`API_KEY`) is the *admin key* — it is the default project's system key, seeded at startup.
#
# Use the admin API to:
# - Create a project for each consuming application
# - Issue a project-scoped key (returned once as plaintext, only SHA-256 hash stored)
# - Rotate or revoke keys without downtime
#
# > **Note:** The `API_KEY` cell at the top must be the admin/default-project key
# > for these cells to work. Application keys issued here should be stored separately.

# %%
import uuid as _uuid

# 6.1 List existing projects
response = requests.get(f"{API_V1}/admin/projects", headers=HEADERS, timeout=30)
print_response(response, "GET /v1/admin/projects")

# %%
# 6.2 Create a new project — returns a one-time plaintext API key
# Store the returned api_key immediately; it is never shown again.
new_project_name = f"demo-app-{_uuid.uuid4().hex[:6]}"

response = requests.post(
    f"{API_V1}/admin/projects",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={"name": new_project_name, "key_label": f"{new_project_name}-key"},
    timeout=30,
)
print_response(response, f"POST /v1/admin/projects  (project: {new_project_name})")

if response.status_code == 201:
    _proj = response.json()
    NEW_PROJECT_ID = _proj["project_id"]
    NEW_PROJECT_KEY = _proj["api_key"]   # ← save this; only shown once
    NEW_KEY_ID      = _proj["key_id"]
    print(f"\nProject ID : {NEW_PROJECT_ID}")
    print(f"API key    : {NEW_PROJECT_KEY}  ← store this immediately")
    print(f"Key ID     : {NEW_KEY_ID}")
else:
    NEW_PROJECT_ID = NEW_PROJECT_KEY = NEW_KEY_ID = None

# %%
# 6.3 Use the new project-scoped key — spans are isolated per project
if NEW_PROJECT_KEY:
    new_proj_headers = {"X-API-Key": NEW_PROJECT_KEY, "Content-Type": "application/json"}
    iso_trace_id = f"demo-isolation-{_uuid.uuid4().hex[:8]}"

    # Write a span with the new project's key
    r = requests.post(
        f"{API_V1}/spans",
        headers=new_proj_headers,
        json={"trace_id": iso_trace_id, "name": "demo.project_span", "kind": "llm.generation"},
        timeout=30,
    )
    print_response(r, f"POST /v1/spans  (new project key)  → span_id")

    # Admin key cannot see this trace (different project)
    r2 = requests.get(f"{API_V1}/traces/{iso_trace_id}/summary", headers=HEADERS, timeout=30)
    print(f"\nAdmin key reads same trace → {r2.status_code} (expect 404 — project isolated)")

    # New project key can read its own trace
    r3 = requests.get(f"{API_V1}/traces/{iso_trace_id}/summary", headers=new_proj_headers, timeout=30)
    print(f"New project key reads same trace → {r3.status_code} (expect 200)")
else:
    print("Skipped — run cell 6.2 first")

# %%
# 6.4 Issue a second key for the same project (key rotation pattern)
if NEW_PROJECT_ID:
    r = requests.post(
        f"{API_V1}/admin/projects/{NEW_PROJECT_ID}/keys",
        headers={**HEADERS, "Content-Type": "application/json"},
        json={"label": f"{new_project_name}-key-v2"},
        timeout=30,
    )
    print_response(r, "POST /v1/admin/projects/{id}/keys  (issue replacement key)")
    if r.status_code == 201:
        REPLACEMENT_KEY_ID = r.json()["key_id"]
        print(f"\nReplacement key ID: {REPLACEMENT_KEY_ID}")
        print("→ Deploy this key to the consuming app, then revoke the old key in cell 6.5")
else:
    print("Skipped — run cell 6.2 first")

# %%
# 6.5 Revoke the original key (after deploying the replacement)
# DELETE /v1/admin/keys/{key_id} — immediate invalidation, no downtime
if NEW_KEY_ID:
    r = requests.delete(f"{API_V1}/admin/keys/{NEW_KEY_ID}", headers=HEADERS, timeout=30)
    print(f"DELETE /v1/admin/keys/{NEW_KEY_ID} → {r.status_code}  (expect 204)")

    # Confirm the revoked key no longer works
    r2 = requests.get(
        f"{API_V1}/analytics/prompts",
        headers={"X-API-Key": NEW_PROJECT_KEY},
        timeout=10,
    )
    print(f"Revoked key attempt → {r2.status_code}  (expect 401)")
else:
    print("Skipped — run cell 6.2 first")

# %% [markdown]
# ---
# ## Part 7: Unified `execute()` — Mode 2 with Auto-Span *(FR-003)*
#
# `POST /v1/executions/run` now accepts a `messages` array (Mode 2) and an optional `span` block.
# When `span.trace_id` is supplied, PromptLedger automatically creates a linked `Span` and returns
# its `span_id` in the response.
#
# **Pattern:**
# ```
# register_code_prompts()          ← once at service startup
#     │
# execute(messages, span=...)      ← each LLM turn; PL calls the LLM + logs span
#     │  returns span_id
#     ▼
# log_span(parent=span_id)         ← optional child spans (guardrail, tool call)
#     │
# GET /v1/traces/{trace_id}/summary  ← cost + token roll-up for the whole run
# ```

# %%
# 7.1 Register a tracking-mode prompt for the execute() demo
# This is the one-time startup call — idempotent, safe to re-run.
response = requests.post(
    f"{API_V1}/prompts/register-code",
    headers=HEADERS,
    json={
        "prompts": [
            {
                "name": "demo.research_agent.turn",
                "template_source": "You are a research assistant. Answer concisely.\n\n{{instructions}}",
            }
        ]
    },
    timeout=30,
)
print_response(response, "7.1 Register prompt for execute() demo")
reg = response.json()
action = reg["details"][0]["action"] if response.status_code == 200 else "error"
print(f"Registration result: {action}")
# Out:
# ...
# ✓ 7.1 Register prompt for execute() demo
# ...
# Status: 200
# {
#   "registered": 0,
#   "updated": 0,
#   "unchanged": 1,
#   "dry_run": false,
#   "details": [
#     {
#       "name": "demo.research_agent.turn",
#       "action": "unchanged",
#       "hash_changed": false,
#       "version": 1,
#       "change_detected": false,
#       "previous_version": null
#     }
#   ]
# }
# ...
#
# Registration result: unchanged

# %%
# 7.2 Single execute() call — messages array + span block
# PL calls the LLM, stores the execution, creates the span, returns span_id.

EXEC_TRACE_ID = f"demo-exec-trace-{uuid.uuid4().hex[:8]}"
print(f"Trace ID: {EXEC_TRACE_ID}")

response = requests.post(
    f"{API_V1}/executions/run",
    headers=HEADERS,
    json={
        "prompt_name": "demo.research_agent.turn",
        "messages": [
            {"role": "system", "content": "You are a concise research assistant."},
            {"role": "user",   "content": "What are the two main benefits of content-based prompt versioning?"},
        ],
        "model": {"provider": "anthropic", "model_name": "claude-haiku-4-5-20251001"},
        "params": {"max_tokens": 150},
        "environment": "demo",
        # span block — tells PL to auto-create a linked span
        "span": {
            "trace_id": EXEC_TRACE_ID,
            "kind": "llm.generation",
            "agent_id": "researcher",
        },
    },
    timeout=60,
)
print_response(response, "7.2 execute() with messages + span")

data = response.json()
TURN_1_SPAN_ID = data.get("span_id")
print(f"span_id returned: {TURN_1_SPAN_ID}")
print(f"response_text:    {data.get('response_text', '')[:120]}...")
# Out:
# Trace ID: demo-exec-trace-616ce987
#
# ...
# ✓ 7.2 execute() with messages + span
# ...
# Status: 200
# {
#   "execution_id": "68206b41-49ba-4b21-bade-4c4671db89b9",
#   "status": "succeeded",
#   "mode": "sync",
#   "response_text": "# Two Main Benefits of Content-Based Prompt Versioning\n\n1. **Automatic Change Detection**: Versions are created only when the prompt content actually changes, eliminating unnecessary versioning from metadata or timestamp updates. This keeps version history clean and meaningful.\n\n2. **Deterministic Reproducibility**: The same prompt content always produces the same version identifier (typically via hashing). This ensures you can reliably reproduce previous results and track which exact prompt was used for any given output, without depending on external version numbers or manual labeling.\n\nThese benefits make content-based versioning particularly useful for maintaining consistency in AI/ML workflows and auditing purposes.",
# ...

# %%
# 7.3 State dict pattern — two sequential execute() calls
#
# The SDK's execute() reads state["trace_id"] / state["phase_span_id"]
# and writes state["last_span_id"] after each call, eliminating manual
# span ID threading. This cell simulates that pattern using raw HTTP
# so you can see exactly what's happening under the hood.
#
# Workflow:
#   Phase span (log_span)
#     └── Turn 1 (execute)  ← parented to phase
#           └── Turn 2 (execute)  ← parented to phase (same level as turn 1)

# -- Phase span --
response = requests.post(
    f"{API_V1}/spans",
    headers=HEADERS,
    json={
        "trace_id": EXEC_TRACE_ID,
        "name": "research_session",
        "kind": "workflow.phase",
        "status": "ok",
    },
    timeout=30,
)
phase_span_id = response.json().get("span_id")
print(f"Phase span ID: {phase_span_id}")

# Simulate the state dict that execute() manages automatically
state = {
    "trace_id":      EXEC_TRACE_ID,
    "phase_span_id": phase_span_id,
    "last_span_id":  None,
}

def execute_turn(messages, agent_id, turn_label):
    """Simulate what AsyncPromptLedgerClient.execute() does under the hood."""
    resp = requests.post(
        f"{API_V1}/executions/run",
        headers=HEADERS,
        json={
            "prompt_name": "demo.research_agent.turn",
            "messages": messages,
            "model": {"provider": "anthropic", "model_name": "claude-haiku-4-5-20251001"},
            "params": {"max_tokens": 100},
            "environment": "demo",
            "span": {
                "trace_id":      state["trace_id"],
                "parent_span_id": state["phase_span_id"],  # parented to phase
                "kind":          "llm.generation",
                "agent_id":      agent_id,
            },
        },
        timeout=60,
    )
    result = resp.json()
    state["last_span_id"] = result.get("span_id")  # write back, just like SDK does
    print(f"\n{turn_label}")
    print(f"  span_id:      {state['last_span_id']}")
    print(f"  latency_ms:   {result.get('telemetry', {}).get('latency_ms')} ms")
    print(f"  total_cost:   ${result.get('telemetry', {}).get('total_cost')}")
    return result

# Turn 1
turn1 = execute_turn(
    messages=[
        {"role": "system", "content": "You are a concise research assistant."},
        {"role": "user",   "content": "Name one advantage of SHA-256 deduplication for prompts."},
    ],
    agent_id="agent_a",
    turn_label="Turn 1 (agent_a)",
)

# Turn 2 — could use turn1's span_id as parent_span_id to nest deeper, but here it's sibling
turn2 = execute_turn(
    messages=[
        {"role": "system", "content": "You are a concise research assistant."},
        {"role": "user",   "content": "What is prompt sprawl in one sentence?"},
    ],
    agent_id="agent_b",
    turn_label="Turn 2 (agent_b)",
)

print(f"\nFinal state['last_span_id']: {state['last_span_id']}")
# Out:
# Phase span ID: a0b8495f-58c8-42ec-b3f6-5d1abd012130
#
# Turn 1 (agent_a)
#   span_id:      01507182-1c4f-405c-a895-95d13bee3b01
#   latency_ms:   2769 ms
#   total_cost:   $0.000348
#
# Turn 2 (agent_b)
#   span_id:      8b2bb719-7775-432a-b57d-6fd28aa39dfe
#   latency_ms:   1101 ms
#   total_cost:   $0.00015520000000000003
#
# Final state['last_span_id']: 8b2bb719-7775-432a-b57d-6fd28aa39dfe

# %%
# 7.4 Trace summary — auto-created spans appear in cost telemetry
# The spans created by execute() in cells 7.2 and 7.3 should appear here
# alongside the manually-logged phase span.
response = requests.get(
    f"{API_V1}/traces/{EXEC_TRACE_ID}/summary",
    headers=HEADERS,
    timeout=30,
)
print_response(response, "7.4 Trace summary (execute() spans included)")

summary = response.json()
print(f"\nSpans in trace:       {summary.get('span_count')}")
print(f"Total prompt tokens:  {summary.get('total_prompt_tokens')}")
print(f"Total completion:     {summary.get('total_completion_tokens')}")
print(f"Total cost:           ${summary.get('total_cost'):.6f}" if summary.get('total_cost') else "Total cost: (no pricing data)")
print(f"\nBy agent:")
for agent in summary.get("by_agent", []):
    print(f"  {agent['agent_id']:12s}  spans={agent['span_count']}  cost=${agent.get('total_cost') or 0:.6f}")
# Out:
# ...
# ✓ 7.4 Trace summary (execute() spans included)
# ...
# Status: 200
# {
#   "trace_id": "demo-exec-trace-616ce987",
#   "span_count": 4,
#   "total_prompt_tokens": 83,
#   "total_completion_tokens": 254,
#   "total_cost": 0.0010824,
#   "cost_breakdown": [
#     {
#       "span_name": "demo.research_agent.turn",
#       "agent_id": "researcher",
#       "cost": 0.0005792000000000001,
#       "provider": "anthropic"
#     },
#     {
#       "span_name": "research_session",
#       "agent_id": null,
#       "cost": null,
#       "provider": null
#     },
#     {
#       "span_name": "demo.research_agent.turn",
#       "agent_id": "agent_a",
#       "cost": 0.000348,
#       "provider": "anthropic"
#     },
#     {
#       "span_name": "demo.research_agent.turn",
#       "agent_id": "agent_b",
#       "cost": 0.00015520000000000003,
#       "provider": "anthropic"
#     }
#   ],
#   "by_agent": [
#     {
#       "agent_id": "researcher",
#       "span_count": 1,
# ...

# %% [markdown]
# ---
# ## Part 8: Async Execution with Span Context *(Epic 3)*
#
# `POST /v1/executions/submit` returns **202 Accepted** immediately and enqueues
# the LLM call in Celery. Include a `span` block with a `trace_id` and the worker
# will create a span under that trace after the provider call completes.
#
# > **Requires:** `ANTHROPIC_API_KEY` set in the Railway service environment,
# > and a running Celery worker.

# %%
# 8.1 Register a prompt for the async demo (idempotent)
ASYNC_PROMPT_NAME = "demo.async_haiku"

response = requests.post(
    f"{API_V1}/prompts/register-code",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={
        "prompts": [
            {
                "name": ASYNC_PROMPT_NAME,
                "template_source": "You are a concise assistant. {{noop}}",
            }
        ]
    },
    timeout=30,
)
print_response(response, "POST /v1/prompts/register-code  (async demo prompt)")

# %%
# 8.2 Submit async execution with span context — expect 202
import uuid as _uuid2

ASYNC_TRACE_ID = f"demo-async-{_uuid2.uuid4().hex[:8]}"

response = requests.post(
    f"{API_V1}/executions/submit",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={
        "prompt_name": ASYNC_PROMPT_NAME,
        "messages": [
            {"role": "system", "content": "You are a concise assistant."},
            {"role": "user",   "content": "Reply with exactly: async ok"},
        ],
        "model": {
            "provider": "anthropic",
            "model_name": "claude-haiku-4-5-20251001",
        },
        "params": {"max_tokens": 10},
        "environment": "demo",
        "span": {
            "trace_id": ASYNC_TRACE_ID,
            "agent_id": "demo_async_worker",
        },
    },
    timeout=30,
)
print_response(response, "POST /v1/executions/submit  (expect 202)")

ASYNC_EXECUTION_ID = response.json().get("execution_id") if response.status_code == 202 else None
print(f"\nExecution ID: {ASYNC_EXECUTION_ID}")
print(f"Trace ID:     {ASYNC_TRACE_ID}")

# %%
# 8.3 Poll until succeeded or failed (max 30s)
if ASYNC_EXECUTION_ID:
    import time as _time
    deadline = _time.time() + 30
    while _time.time() < deadline:
        poll = requests.get(
            f"{API_V1}/executions/{ASYNC_EXECUTION_ID}",
            headers=HEADERS,
            timeout=10,
        )
        status = poll.json().get("status")
        print(f"  status: {status}")
        if status in ("succeeded", "failed"):
            break
        _time.sleep(3)

    print_response(poll, "GET /v1/executions/{id}  (final)")
else:
    print("Skipped — run cell 8.2 first")

# %%
# 8.4 Worker-created span appears in trace summary
# The Celery worker writes the span after the provider responds.
# Run this after cell 8.3 confirms status=succeeded.
response = requests.get(
    f"{API_V1}/traces/{ASYNC_TRACE_ID}/summary",
    headers=HEADERS,
    timeout=30,
)
print_response(response, f"GET /v1/traces/{ASYNC_TRACE_ID}/summary")

if response.status_code == 200:
    s = response.json()
    print(f"\nspan_count          : {s['span_count']}")
    print(f"total_prompt_tokens : {s['total_prompt_tokens']}")
    print(f"total_cost          : {s['total_cost']}")
    for agent in s.get("by_agent", []):
        print(f"  agent {agent['agent_id']:30s}  spans={agent['span_count']}")

# %% [markdown]
# ---
# ## Part 9: Structured Tool Call Capture *(Epic 4)*
#
# Tool call spans use `kind="tool"` with first-class structured fields:
# - `tool_name` — stable identifier (indexed, used for analytics aggregation)
# - `success` — boolean success flag
# - `tool_args` / `tool_result` — JSONB blobs (caller-shaped)
#
# `GET /v1/analytics/tools` returns error rates and average latency per `tool_name`
# across all runs, so you can identify which tools are slow or failing.
#
# Use `parent_span_id` to nest tool call spans under the agent-turn span that
# triggered them (the `span_id` returned by `execute()` or `log_span()`).

# %%
# 9.1 Log a successful tool call span
import uuid as _uuid3

TOOL_TRACE_ID = f"demo-tool-{_uuid3.uuid4().hex[:8]}"

response = requests.post(
    f"{API_V1}/spans",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={
        "trace_id": TOOL_TRACE_ID,
        "name": "web_search_call",
        "kind": "tool",
        "tool_name": "web_search",
        "tool_args": {"query": "climate change IPCC 2023"},
        "tool_result": {"hits": [{"title": "IPCC AR6 Report"}, {"title": "NASA climate data"}]},
        "success": True,
        "duration_ms": 340,
        "status": "ok",
        "agent_id": "demo_researcher",
    },
    timeout=30,
)
print_response(response, "POST /v1/spans  (kind=tool, success=True)")

TOOL_SPAN_ID = response.json().get("span_id") if response.status_code == 201 else None
print(f"\nTool span_id: {TOOL_SPAN_ID}")

# %%
# 9.2 Log a failed tool call — note success=False and status="error"
response = requests.post(
    f"{API_V1}/spans",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={
        "trace_id": TOOL_TRACE_ID,
        "name": "db_lookup_call",
        "kind": "tool",
        "tool_name": "db_lookup",
        "tool_args": {"id": "doc-42"},
        "tool_result": {"error_type": "TimeoutError"},
        "success": False,
        "duration_ms": 5000,
        "status": "error",
        "error_message": "connection timed out after 5 s",
        "agent_id": "demo_researcher",
    },
    timeout=30,
)
print_response(response, "POST /v1/spans  (kind=tool, success=False)")

# 9.3 Validation: kind=tool without tool_name → expect 422
r_bad = requests.post(
    f"{API_V1}/spans",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={"trace_id": TOOL_TRACE_ID, "name": "bad_span", "kind": "tool"},
    timeout=30,
)
print(f"\nMissing tool_name  → {r_bad.status_code}  (expect 422)")

# 9.4 Validation: non-tool span with tool_name → expect 422
r_bad2 = requests.post(
    f"{API_V1}/spans",
    headers={**HEADERS, "Content-Type": "application/json"},
    json={"trace_id": TOOL_TRACE_ID, "name": "llm_span", "kind": "llm.generation",
          "tool_name": "web_search"},
    timeout=30,
)
print(f"tool_name on llm span → {r_bad2.status_code}  (expect 422)")

# %%
# 9.5 Tool fields appear in trace tree
response = requests.get(f"{API_V1}/traces/{TOOL_TRACE_ID}", headers=HEADERS, timeout=30)
print_response(response, f"GET /v1/traces/{TOOL_TRACE_ID}")

if response.status_code == 200:
    for span in response.json().get("spans", []):
        print(f"\n  span: {span['name']}")
        print(f"    kind       : {span['kind']}")
        print(f"    tool_name  : {span.get('tool_name')}")
        print(f"    success    : {span.get('success')}")

# %%
# 9.6 Tool analytics — error rate and latency per tool_name (project-scoped)
response = requests.get(f"{API_V1}/analytics/tools", headers=HEADERS, timeout=30)
print_response(response, "GET /v1/analytics/tools")

if response.status_code == 200:
    print(f"\n{'tool_name':25s}  {'calls':>6}  {'error_rate':>12}  {'avg_ms':>8}")
    print("-" * 60)
    for t in response.json():
        print(f"{t['tool_name']:25s}  {t['call_count']:6d}  {t['error_rate']:12.1%}  {t['avg_duration_ms']:8d}ms")

# Optional: filter to last 24h
# response = requests.get(
#     f"{API_V1}/analytics/tools?from=2026-03-18T00:00:00Z",
#     headers=HEADERS, timeout=30,
# )
